# %% [markdown]
# 17.01.2024
#
# Регистрация на площадках
# https://github.com/
# https://codeforces.com/
# https://leetcode.com/
# https://www.kaggle.com/
# https://ods.ai/
#
# скачал
# https://code.visualstudio.com/
# https://www.anaconda.com/download
# https://git-scm.com/
#
# Разбирались в гитхабе и гите с создания репозитория.
# Заходим в гитхабе на SENATOROVAI и выбираем проект. Ставим звездочку(чтобы поднять в поиске и отметить, что понравилось) и fork. Затем идем к себе в профиль и ищем скопированный репозиторий(?), жму на зеленые кнопку CODE и копирую url. Далее в VSCode иду во вкладку гита и систему управление версиями -> три точки -> клонировать -> вставляю ссылку с гитхаба и завожу на локалку репозиторий(отображаться будет в Репозитории Системы управления версиями).
#
# Для изменения уже в чьем то репозитории файлов:
# захожу туда, нажимаю на карандаш, вношу изменения, Pull requirest, создаю новый, далее называю его.
#
# Создался могу посмотреть Commits где и в последней вкладке что именно поменялось.
# Ответить на это исправление.
