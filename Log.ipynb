# %% [markdown]
# 16.01.24
#
# 1) Начало рабоыт с гитхабом.
# 2) Последовательность действий:
# -захожу SENATOROVAI.
# -Создаю свой репозиторий,
# -кланирую с помомщбю Fork себе уже имеющийся репозиторий.
#
# Для изменения уже в чьем то репозитории файлов:
# захожу туда,
# нажимаю на карандаш,
# вношу изменения,
# Pull requirest,
# создаю новый,
# далее называю его.
#
# Создался могу посмотреть Commits где и в последней вкладке что именно поменялось.
# Ответить на это исправление.
#
# Также была пройдена работа в visual code как исправлять и добавлять, отправляь и принимать новый файлы.
